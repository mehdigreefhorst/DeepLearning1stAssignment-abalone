# %% [markdown]
# # Project Evaluation Criteria
#
# ## Data Loading and Preprocessing (2 points max)
# - Load the data from the CSV files using the appropriate data import methods in PyTorch.
# - Apply dataset splits that enable you to assess network overfitting.
# - Preprocess the categorical and numerical data accordingly (refer to **Lesson 5 – Training Practices and Regularization** and **Lesson 6 – PyTorch in Production**).
# - Make data loading protocols for mini-batch training.
#
# ## Approach and Methodology (2 points max)
# - Implement a neural network architecture suited to the task and justify your choice (refer to **Lesson 6 – PyTorch in Production**).
# - Apply regularization techniques that help prevent network overfitting.
#
# ## Results and Evaluation (2 points max)
# - Build a training protocol to train your neural network on the dataset with a user-specified number of epochs.
# - Implement methods that effectively regulate the training process (refer to **Lab 5 – Training Practices and Regularization**).
# - Provide visualizations, if useful, that give an indication of the training procedure (e.g., a loss curve). These visualizations can be included in your report as part of your submission package.
# - Implement a software method that saves the network’s weight with the best performance.
#   - These network weights should be saved as `.pt` / `.pth` file.
#   - Include them as part of your submission package so that the teacher and the teaching assistant can reproduce your results.
#
# ## Code Quality and Reproducibility (2 points max)
# - Your code should be clean, well-structured, and properly commented.
# - Ensure the code runs in inference mode with your network weights (`.pt` / `.pth` file) to produce the target variable (the number of rings) using the data from `test.csv`.
# - Ensure that the model generates predictions for the number of rings for every data point in the test set.
# - Write a `README` file for running your code in inference mode to produce the targets.
#   - This will help the teacher and the teaching assistant reproduce your results.
#
# ## Summary and Justification (2 points max)
# - Clearly summarize the key novelties of your approach.
# - Justify the choices made in the data preprocessing, neural network design, training protocol, and inference protocol.
# - Discuss any challenges encountered and potential improvements.

# %% [markdown]
# ## Importing the data

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will choose to use standardization because it includes the variance of the score. As we can see from the data ranges there may be outliers. And outliers may affect the the score a lot when we use the normalization route. We will only do this for the numerical columns and not the categorical column "Sex".

# %% [markdown]
# ### Load and initiate the data
#
# To prevent clutter we have moved the loading of the data to the file data_load.py. The loading of the data should not change because the data stays constant. All of  the other functions could change, therefore we leave them in the notebooks for easier change of functions.

# %%
from data_load import AbalonDataset


class AbalonDataset(Dataset):
    def __init__(self, data_df, train_dataset: "AbalonDataset" = None):
        """if train_dataset is provided, then it is assumed that this dataset must be the test dataset. We then access the mean and std of the provided dataset"""
        self.data = data_df
        #standardized_data = 
        if train_dataset is None:
            # We only want to split train and val set when the provided dataset is the train dataset so not the test dataset 
            # we only want to calculate the mean and std based on the train set
            self.mean = self.get_mean(self.data)
            self.std = self.get_std(self.data)
        else:
            self.mean = train_dataset.mean
            self.std = train_dataset.std
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        """we first take the row, then we pop Rings and Sex. Then we make a sex tensor which is a category, 
        then we make tensors of the numerical columns. We combine the sex and numerical into features. We also make a tensor of the dependent variable: Rings"""
        row = self.preprocess_data(self.data.iloc[index])
        target_col = None
        if "Rings" in row:
            target_col = row.pop("Rings")
        sex_feature = row.pop("Sex")
        # we make the sex tensor separate because it must be onehot encoded
        sex_tensor = torch.nn.functional.one_hot(torch.tensor(sex_feature, dtype=torch.long), num_classes=3).to(torch.float32)
        numerical_tensor = torch.tensor(row, dtype=torch.float32)
        # standardize the numerical features
        standardized_numerical_tensor = (numerical_tensor - self.mean) / (4* self.std)
        features = torch.concat([sex_tensor, standardized_numerical_tensor])

        # when target_col is none, the data is training or validation data
        if target_col is not None:
            target = torch.tensor(target_col, dtype=torch.float32).view(1)
        # in case the dataset is the test dataset where there is no Rings column, we need to create an empty target
        else:
            target = torch.tensor([0])
        return features, target

    @staticmethod
    def preprocess_data(row):
        """preproces data of sex to numerical values"""
        sex_map = {"M": 0, "F": 1, "I": 2}
        row = row.copy()
        row["Sex"] = sex_map[row["Sex"]]
        return row
    
    @staticmethod
    def get_mean(df):
        data = df.drop(["Sex", "Rings"], axis=1)
        return torch.tensor(data.mean().values, dtype=torch.float32)
    
    @staticmethod
    def get_std(df):
        data = df.drop(["Sex", "Rings"], axis=1)
        return torch.tensor(data.std().values, dtype=torch.float32)
    
    @classmethod
    def create_train_test_val(cls, csv_file_name, train_dataset: "AbalonDataset" = None):
        """class method to create a train test and val object of the AbalonDataset"""
        data = pd.read_csv(f"data/{csv_file_name}")
        if train_dataset is None:
            train_df, val_df = train_test_split(data, test_size = 0.2)
            trainAbalone = cls(train_df)
            valAbalone = cls(val_df, trainAbalone)
            return trainAbalone, valAbalone
        else:
            return cls(data, train_dataset)

def load_data(batch_size):

    train_dataset, test_dataset = AbalonDataset.create_train_test_val("train.csv")
    val_dataset = AbalonDataset.create_train_test_val("test.csv", train_dataset)

    train_loader = DataLoader(train_dataset, batch_size=batch_size)
    val_loader = DataLoader(test_dataset, batch_size=batch_size)
    test_loader = DataLoader(val_dataset, batch_size=batch_size)

    return train_loader, val_loader, test_loader

# %% [markdown]
# ## Setup model
# We setup the model with two hidden layers and a Tanh activation function.

# %%
class AbaloneNetworkTwoLayer(nn.Module):
    def __init__(self, num_inputs, num_hidden, num_outputs):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(num_inputs, num_hidden),
            nn.Tanh(),            
            nn.Linear(num_hidden, num_hidden),
            nn.Tanh(),
            nn.Linear(num_hidden, num_outputs))

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Setup the training cycle of the model

# %%
def l1_regularization(model, lambda_reg):
    l1_penalty = sum(param.abs().sum() for param in model.parameters())
    return lambda_reg * l1_penalty

def l2_regularization(model, lambda_reg):
    l2_penalty = sum(param.pow(2).sum() for param in model.parameters())
    return lambda_reg * l2_penalty

def train_model(model, train_loader, optimizer, device, criterion, val_loader, lambda_reg=None):
    model.train()
    train_loss = 0.0

    for inputs_load, targets_load in train_loader:
        inputs, targets = inputs_load.to(device), targets_load.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        # only do regularization when lambda_reg has been passed to it.
        if lambda_reg is not None:
            loss += l2_regularization(model, lambda_reg)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss /= len(train_loader)  # Compute average train loss

    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_loss += loss.item()
        

        
        val_loss /= len(val_loader)  # Compute average validation loss
    return train_loss, val_loss

# %% [markdown]
# ## Plot the model results

# %%
def plot_figure(numepochs, trainlosses, vallosses):
    # Plot the loss curves
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, numepochs + 1), trainlosses, label="Train Loss", marker="o")
    plt.plot(range(1, numepochs + 1), vallosses, label="Validation Loss", marker="o")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training and Validation Loss Over Epochs")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Train the complete model for its epochs

# %%
from statistics import mean
def train_setup_epochs(train_loader, val_loader, model, optimizer, device, criterion, num_epochs, lambda_reg=None, stop_converge = False):
    
    best_val_loss = float("inf")

    train_losses = []
    val_losses = []
    for epoch in range(num_epochs):
        train_loss, val_loss = train_model(model, train_loader, optimizer, device, criterion, val_loader, lambda_reg)
        train_losses.append(train_loss)
        val_losses.append(val_loss)


        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model, "best_model_running.pth")
            print("Saved Best Model")
        
        # if the mean of the previous three epochs is not improving anymore we stop. if improvement is less than 0.1% we stop
        if stop_converge:
            previous_3_epochs = val_losses[max(0, epoch-3): epoch]
            if previous_3_epochs:
                if val_loss *0.9999 > mean(previous_3_epochs):
                    print("model converged, it stopped improving at epoch: ", epoch)
                    break
    return train_losses, val_losses, epoch +1

# %% [markdown]
# ## Run the model and training
#
# We implement a two hidden layer neural network with 12 neurons. As from our experimentation this seemed to perform the best. THe hyperparameters of the optimizer have
# - learning rate = 5e-3
# - Weight decay = 1e-6
# - momentum = 0.9

# %% [markdown]
# ### Run model without regularization

# %%
trainloader, valloader, testloader = load_data(batch_size=16)
model_abalone = AbaloneNetworkTwoLayer(10, 12, 1)
device = torch.device("cpu")
model_abalone.to(device)
criterion_l1 = nn.L1Loss()
optimizer_sgd = optim.SGD(model_abalone.parameters(), lr=5e-3, weight_decay=1e-6, momentum=0.9)
epochs = 100
train_loss_list, val_loss_list, epochs_done = train_setup_epochs(
    train_loader = trainloader,
    val_loader=valloader, 
    model=model_abalone, 
    optimizer=optimizer_sgd, 
    device=device, 
    criterion=criterion_l1, 
    num_epochs=epochs)

plot_figure(epochs_done, train_loss_list, val_loss_list)
# Out:
# /var/folders/f3/ykt1vfz96xz48try_trwdn440000gn/T/ipykernel_34353/3458330381.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   numerical_tensor = torch.tensor(row, dtype=torch.float32)
# Epoch 1/100, Train Loss: 3.6255, Val Loss: 1.7738
# Saved Best Model
# Epoch 2/100, Train Loss: 1.7478, Val Loss: 1.7656
# Saved Best Model
# Epoch 3/100, Train Loss: 1.7281, Val Loss: 1.7398
# Saved Best Model
# Epoch 4/100, Train Loss: 1.7096, Val Loss: 1.7036
# Saved Best Model
# Epoch 5/100, Train Loss: 1.6805, Val Loss: 1.6727
# Saved Best Model
# Epoch 6/100, Train Loss: 1.6433, Val Loss: 1.6833
# Epoch 7/100, Train Loss: 1.6280, Val Loss: 1.6063
# Saved Best Model
# Epoch 8/100, Train Loss: 1.6070, Val Loss: 1.5895
# Saved Best Model
# Epoch 9/100, Train Loss: 1.5948, Val Loss: 1.5646
# Saved Best Model
# Epoch 10/100, Train Loss: 1.5905, Val Loss: 1.5798
# Epoch 11/100, Train Loss: 1.5877, Val Loss: 1.5492
# Saved Best Model
# Epoch 12/100, Train Loss: 1.5745, Val Loss: 1.5330
# Saved Best Model
# Epoch 13/100, Train Loss: 1.5653, Val Loss: 1.5149
# Saved Best Model
# Epoch 14/100, Train Loss: 1.5636, Val Loss: 1.5066
# Saved Best Model
# Epoch 15/100, Train Loss: 1.5512, Val Loss: 1.5040
# Saved Best Model
# Epoch 16/100, Train Loss: 1.5347, Val Loss: 1.4886
# Saved Best Model
# Epoch 17/100, Train Loss: 1.5303, Val Loss: 1.4833
# Saved Best Model
# Epoch 18/100, Train Loss: 1.5197, Val Loss: 1.4750
# Saved Best Model
# Epoch 19/100, Train Loss: 1.5216, Val Loss: 1.4724
# Saved Best Model
# Epoch 20/100, Train Loss: 1.5090, Val Loss: 1.4749
# Epoch 21/100, Train Loss: 1.5094, Val Loss: 1.4684
# Saved Best Model
# Epoch 22/100, Train Loss: 1.5063, Val Loss: 1.4731
# Epoch 23/100, Train Loss: 1.4959, Val Loss: 1.4606
# Saved Best Model
# Epoch 24/100, Train Loss: 1.4999, Val Loss: 1.4610
# Epoch 25/100, Train Loss: 1.4960, Val Loss: 1.4617
# Epoch 26/100, Train Loss: 1.4889, Val Loss: 1.4614
# Epoch 27/100, Train Loss: 1.4866, Val Loss: 1.4566
# Saved Best Model
# Epoch 28/100, Train Loss: 1.4906, Val Loss: 1.4538
# Saved Best Model
# Epoch 29/100, Train Loss: 1.4855, Val Loss: 1.4535
# Saved Best Model
# Epoch 30/100, Train Loss: 1.4811, Val Loss: 1.4503
# Saved Best Model
# Epoch 31/100, Train Loss: 1.4867, Val Loss: 1.4712
# Epoch 32/100, Train Loss: 1.4784, Val Loss: 1.4530
# Epoch 33/100, Train Loss: 1.4763, Val Loss: 1.4436
# Saved Best Model
# Epoch 34/100, Train Loss: 1.4743, Val Loss: 1.4470
# Epoch 35/100, Train Loss: 1.4729, Val Loss: 1.4450
# Epoch 36/100, Train Loss: 1.4749, Val Loss: 1.4390
# Saved Best Model
# Epoch 37/100, Train Loss: 1.4723, Val Loss: 1.4479
# Epoch 38/100, Train Loss: 1.4699, Val Loss: 1.4435
# Epoch 39/100, Train Loss: 1.4731, Val Loss: 1.4602
# Epoch 40/100, Train Loss: 1.4633, Val Loss: 1.4556
# Epoch 41/100, Train Loss: 1.4653, Val Loss: 1.4372
# Saved Best Model
# Epoch 42/100, Train Loss: 1.4673, Val Loss: 1.4503
# Epoch 43/100, Train Loss: 1.4649, Val Loss: 1.4783
# Epoch 44/100, Train Loss: 1.4654, Val Loss: 1.4508
# Epoch 45/100, Train Loss: 1.4655, Val Loss: 1.4742
# Epoch 46/100, Train Loss: 1.4637, Val Loss: 1.4786
# Epoch 47/100, Train Loss: 1.4625, Val Loss: 1.4702
# Epoch 48/100, Train Loss: 1.4645, Val Loss: 1.4785
# Epoch 49/100, Train Loss: 1.4640, Val Loss: 1.4670
# Epoch 50/100, Train Loss: 1.4584, Val Loss: 1.4687
# Epoch 51/100, Train Loss: 1.4586, Val Loss: 1.4545
# Epoch 52/100, Train Loss: 1.4631, Val Loss: 1.4682
# Epoch 53/100, Train Loss: 1.4627, Val Loss: 1.4682
# Epoch 54/100, Train Loss: 1.4598, Val Loss: 1.4756
# Epoch 55/100, Train Loss: 1.4601, Val Loss: 1.4510
# Epoch 56/100, Train Loss: 1.4589, Val Loss: 1.4523
# Epoch 57/100, Train Loss: 1.4578, Val Loss: 1.4542
# Epoch 58/100, Train Loss: 1.4564, Val Loss: 1.4667
# Epoch 59/100, Train Loss: 1.4611, Val Loss: 1.4665
# Epoch 60/100, Train Loss: 1.4613, Val Loss: 1.4639
# Epoch 61/100, Train Loss: 1.4566, Val Loss: 1.4497
# Epoch 62/100, Train Loss: 1.4559, Val Loss: 1.4722
# Epoch 63/100, Train Loss: 1.4596, Val Loss: 1.4531
# Epoch 64/100, Train Loss: 1.4550, Val Loss: 1.4713
# Epoch 65/100, Train Loss: 1.4618, Val Loss: 1.4737
# Epoch 66/100, Train Loss: 1.4568, Val Loss: 1.4808
# Epoch 67/100, Train Loss: 1.4582, Val Loss: 1.4653
# Epoch 68/100, Train Loss: 1.4557, Val Loss: 1.4631
# Epoch 69/100, Train Loss: 1.4548, Val Loss: 1.4625
# Epoch 70/100, Train Loss: 1.4529, Val Loss: 1.4588
# Epoch 71/100, Train Loss: 1.4529, Val Loss: 1.4679
# Epoch 72/100, Train Loss: 1.4541, Val Loss: 1.4652
# Epoch 73/100, Train Loss: 1.4561, Val Loss: 1.4796
# Epoch 74/100, Train Loss: 1.4529, Val Loss: 1.4741
# Epoch 75/100, Train Loss: 1.4517, Val Loss: 1.4665
# Epoch 76/100, Train Loss: 1.4503, Val Loss: 1.4763
# Epoch 77/100, Train Loss: 1.4495, Val Loss: 1.4811
# Epoch 78/100, Train Loss: 1.4495, Val Loss: 1.4728
# Epoch 79/100, Train Loss: 1.4495, Val Loss: 1.4717
# Epoch 80/100, Train Loss: 1.4505, Val Loss: 1.4781
# Epoch 81/100, Train Loss: 1.4473, Val Loss: 1.4545
# Epoch 82/100, Train Loss: 1.4482, Val Loss: 1.4688
# Epoch 83/100, Train Loss: 1.4495, Val Loss: 1.4603
# Epoch 84/100, Train Loss: 1.4433, Val Loss: 1.4626
# Epoch 85/100, Train Loss: 1.4434, Val Loss: 1.4707
# Epoch 86/100, Train Loss: 1.4458, Val Loss: 1.4652
# Epoch 87/100, Train Loss: 1.4440, Val Loss: 1.4602
# Epoch 88/100, Train Loss: 1.4455, Val Loss: 1.4613
# Epoch 89/100, Train Loss: 1.4419, Val Loss: 1.4578
# Epoch 90/100, Train Loss: 1.4437, Val Loss: 1.4670
# Epoch 91/100, Train Loss: 1.4388, Val Loss: 1.4616
# Epoch 92/100, Train Loss: 1.4420, Val Loss: 1.4701
# Epoch 93/100, Train Loss: 1.4431, Val Loss: 1.4671
# Epoch 94/100, Train Loss: 1.4400, Val Loss: 1.4609
# Epoch 95/100, Train Loss: 1.4390, Val Loss: 1.4593
# Epoch 96/100, Train Loss: 1.4384, Val Loss: 1.4587
# Epoch 97/100, Train Loss: 1.4364, Val Loss: 1.4712
# Epoch 98/100, Train Loss: 1.4404, Val Loss: 1.4577
# Epoch 99/100, Train Loss: 1.4385, Val Loss: 1.4752
# Epoch 100/100, Train Loss: 1.4375, Val Loss: 1.4549

# %% [markdown]
# ### Run model with regularization
#
# We choose to implement L1 regularization. As we are also using the L1 loss, so this seems like a smart choice. However we do not seem to worse results when L1 regularization is implemented, L2 regularization has also been explored but it yielded similar results the L1 regulurization.

# %%
trainloader, valloader, testloader = load_data(batch_size=16)
model_abalone = AbaloneNetworkTwoLayer(10, 12, 1)
device = torch.device("cpu")
model_abalone.to(device)
criterion_l1 = nn.L1Loss()
optimizer_sgd = optim.SGD(model_abalone.parameters(), lr=5e-3, weight_decay=1e-6, momentum=0.9)
epochs = 100
lambda_reg_score = 1e-5
train_loss_list, val_loss_list, epochs_done = train_setup_epochs(train_loader = trainloader,
                                                    val_loader=valloader, 
                                                    model=model_abalone, 
                                                    optimizer=optimizer_sgd, 
                                                    device=device, 
                                                    criterion=criterion_l1, 
                                                    num_epochs=epochs,
                                                    lambda_reg=lambda_reg_score,
                                                    stop_converge=False)
plot_figure(epochs_done, train_loss_list, val_loss_list)
# Out:
# /var/folders/f3/ykt1vfz96xz48try_trwdn440000gn/T/ipykernel_10237/3458330381.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   numerical_tensor = torch.tensor(row, dtype=torch.float32)
# Epoch 1/100, Train Loss: 3.7886, Val Loss: 1.7261
# Saved Best Model
# Epoch 2/100, Train Loss: 1.7774, Val Loss: 1.6810
# Saved Best Model
# Epoch 3/100, Train Loss: 1.7647, Val Loss: 1.6379
# Saved Best Model
# Epoch 4/100, Train Loss: 1.7413, Val Loss: 1.5941
# Saved Best Model
# Epoch 5/100, Train Loss: 1.7064, Val Loss: 1.5578
# Saved Best Model
# Epoch 6/100, Train Loss: 1.6630, Val Loss: 1.5461
# Saved Best Model
# Epoch 7/100, Train Loss: 1.6314, Val Loss: 1.6055
# Epoch 8/100, Train Loss: 1.6193, Val Loss: 1.5449
# Saved Best Model
# Epoch 9/100, Train Loss: 1.6156, Val Loss: 1.5741
# Epoch 10/100, Train Loss: 1.6003, Val Loss: 1.4774
# Saved Best Model
# Epoch 11/100, Train Loss: 1.5812, Val Loss: 1.4675
# Saved Best Model
# Epoch 12/100, Train Loss: 1.5684, Val Loss: 1.4558
# Saved Best Model
# Epoch 13/100, Train Loss: 1.5582, Val Loss: 1.4605
# Epoch 14/100, Train Loss: 1.5464, Val Loss: 1.4498
# Saved Best Model
# Epoch 15/100, Train Loss: 1.5387, Val Loss: 1.4443
# Saved Best Model
# Epoch 16/100, Train Loss: 1.5264, Val Loss: 1.4487
# Epoch 17/100, Train Loss: 1.5299, Val Loss: 1.4587
# Epoch 18/100, Train Loss: 1.5189, Val Loss: 1.4433
# Saved Best Model
# Epoch 19/100, Train Loss: 1.5163, Val Loss: 1.4380
# Saved Best Model
# Epoch 20/100, Train Loss: 1.5064, Val Loss: 1.4571
# Epoch 21/100, Train Loss: 1.5092, Val Loss: 1.4347
# Saved Best Model
# Epoch 22/100, Train Loss: 1.5051, Val Loss: 1.4358
# Epoch 23/100, Train Loss: 1.4996, Val Loss: 1.4380
# Epoch 24/100, Train Loss: 1.4956, Val Loss: 1.4182
# Saved Best Model
# Epoch 25/100, Train Loss: 1.4905, Val Loss: 1.4209
# Epoch 26/100, Train Loss: 1.4889, Val Loss: 1.4200
# Epoch 27/100, Train Loss: 1.4857, Val Loss: 1.4242
# Epoch 28/100, Train Loss: 1.4922, Val Loss: 1.4171
# Saved Best Model
# Epoch 29/100, Train Loss: 1.4831, Val Loss: 1.4190
# Epoch 30/100, Train Loss: 1.4774, Val Loss: 1.4171
# Saved Best Model
# Epoch 31/100, Train Loss: 1.4812, Val Loss: 1.4221
# Epoch 32/100, Train Loss: 1.4774, Val Loss: 1.4177
# Epoch 33/100, Train Loss: 1.4765, Val Loss: 1.4147
# Saved Best Model
# Epoch 34/100, Train Loss: 1.4758, Val Loss: 1.4214
# Epoch 35/100, Train Loss: 1.4693, Val Loss: 1.4197
# Epoch 36/100, Train Loss: 1.4738, Val Loss: 1.4144
# Saved Best Model
# Epoch 37/100, Train Loss: 1.4678, Val Loss: 1.4166
# Epoch 38/100, Train Loss: 1.4689, Val Loss: 1.4153
# Epoch 39/100, Train Loss: 1.4724, Val Loss: 1.4146
# Epoch 40/100, Train Loss: 1.4715, Val Loss: 1.4182
# Epoch 41/100, Train Loss: 1.4690, Val Loss: 1.4147
# Epoch 42/100, Train Loss: 1.4668, Val Loss: 1.4158
# Epoch 43/100, Train Loss: 1.4662, Val Loss: 1.4104
# Saved Best Model
# Epoch 44/100, Train Loss: 1.4666, Val Loss: 1.4198
# Epoch 45/100, Train Loss: 1.4669, Val Loss: 1.4253
# Epoch 46/100, Train Loss: 1.4664, Val Loss: 1.4158
# Epoch 47/100, Train Loss: 1.4647, Val Loss: 1.4209
# Epoch 48/100, Train Loss: 1.4648, Val Loss: 1.4131
# Epoch 49/100, Train Loss: 1.4644, Val Loss: 1.4181
# Epoch 50/100, Train Loss: 1.4663, Val Loss: 1.4106
# Epoch 51/100, Train Loss: 1.4612, Val Loss: 1.4135
# Epoch 52/100, Train Loss: 1.4636, Val Loss: 1.4124
# Epoch 53/100, Train Loss: 1.4600, Val Loss: 1.4141
# Epoch 54/100, Train Loss: 1.4597, Val Loss: 1.4175
# Epoch 55/100, Train Loss: 1.4594, Val Loss: 1.4179
# Epoch 56/100, Train Loss: 1.4615, Val Loss: 1.4121
# Epoch 57/100, Train Loss: 1.4588, Val Loss: 1.4175
# Epoch 58/100, Train Loss: 1.4556, Val Loss: 1.4160
# Epoch 59/100, Train Loss: 1.4596, Val Loss: 1.4088
# Saved Best Model
# Epoch 60/100, Train Loss: 1.4598, Val Loss: 1.4225
# Epoch 61/100, Train Loss: 1.4598, Val Loss: 1.4193
# Epoch 62/100, Train Loss: 1.4576, Val Loss: 1.4124
# Epoch 63/100, Train Loss: 1.4603, Val Loss: 1.4177
# Epoch 64/100, Train Loss: 1.4548, Val Loss: 1.4147
# Epoch 65/100, Train Loss: 1.4569, Val Loss: 1.4213
# Epoch 66/100, Train Loss: 1.4563, Val Loss: 1.4208
# Epoch 67/100, Train Loss: 1.4569, Val Loss: 1.4182
# Epoch 68/100, Train Loss: 1.4550, Val Loss: 1.4245
# Epoch 69/100, Train Loss: 1.4575, Val Loss: 1.4135
# Epoch 70/100, Train Loss: 1.4538, Val Loss: 1.4168
# Epoch 71/100, Train Loss: 1.4586, Val Loss: 1.4142
# Epoch 72/100, Train Loss: 1.4605, Val Loss: 1.4229
# Epoch 73/100, Train Loss: 1.4547, Val Loss: 1.4249
# Epoch 74/100, Train Loss: 1.4557, Val Loss: 1.4219
# Epoch 75/100, Train Loss: 1.4515, Val Loss: 1.4194
# Epoch 76/100, Train Loss: 1.4521, Val Loss: 1.4116
# Epoch 77/100, Train Loss: 1.4534, Val Loss: 1.4228
# Epoch 78/100, Train Loss: 1.4588, Val Loss: 1.4268
# Epoch 79/100, Train Loss: 1.4528, Val Loss: 1.4145
# Epoch 80/100, Train Loss: 1.4611, Val Loss: 1.4346
# Epoch 81/100, Train Loss: 1.4543, Val Loss: 1.4187
# Epoch 82/100, Train Loss: 1.4528, Val Loss: 1.4321
# Epoch 83/100, Train Loss: 1.4530, Val Loss: 1.4299
# Epoch 84/100, Train Loss: 1.4524, Val Loss: 1.4241
# Epoch 85/100, Train Loss: 1.4492, Val Loss: 1.4317
# Epoch 86/100, Train Loss: 1.4530, Val Loss: 1.4317
# Epoch 87/100, Train Loss: 1.4519, Val Loss: 1.4118
# Epoch 88/100, Train Loss: 1.4553, Val Loss: 1.4204
# Epoch 89/100, Train Loss: 1.4535, Val Loss: 1.4106
# Epoch 90/100, Train Loss: 1.4474, Val Loss: 1.4179
# Epoch 91/100, Train Loss: 1.4590, Val Loss: 1.4251
# Epoch 92/100, Train Loss: 1.4493, Val Loss: 1.4262
# Epoch 93/100, Train Loss: 1.4513, Val Loss: 1.4236
# Epoch 94/100, Train Loss: 1.4499, Val Loss: 1.4161
# Epoch 95/100, Train Loss: 1.4519, Val Loss: 1.4206
# Epoch 96/100, Train Loss: 1.4479, Val Loss: 1.4175
# Epoch 97/100, Train Loss: 1.4543, Val Loss: 1.4174
# Epoch 98/100, Train Loss: 1.4493, Val Loss: 1.4163
# Epoch 99/100, Train Loss: 1.4522, Val Loss: 1.4254
# Epoch 100/100, Train Loss: 1.4481, Val Loss: 1.4180

# %% [markdown]
# ### Create final predictions of the final test.csv

# %%
def create_predicted_csv(model_or_saved, test_loader, device):
    """if you set the model_or_saved to None or False, you use the torch pth file to load the model. You can also provide 
    model as parameter, then it will work based on the provided model"""
    if not model_or_saved:
        model = torch.load("best_model.pth", weights_only=False)
    else:
        model = model_or_saved
    model.eval()
    final_predictions = []
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            final_predictions.extend([round(float(output), 2) for output in outputs])
    
    final_df = pd.read_csv("data/test.csv")
    final_df["prediction"] = final_predictions
    final_df.to_csv("data/final.csv")
    final_df.to_markdown("final_test.md")

    return "correctly saved into final_test.csv the predictions + original data"

#print(create_predicted_csv(model_abalone, testloader))
print(create_predicted_csv(False, testloader, device))
# Out:
# /var/folders/f3/ykt1vfz96xz48try_trwdn440000gn/T/ipykernel_10237/3458330381.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   numerical_tensor = torch.tensor(row, dtype=torch.float32)
# correctly saved into final_test.csv the predictions + original data

# %% [markdown]
# # Notes for the report pdf
#
# ### The text below doesn't hava a place in the jupyter notebook so we add remarks during the process

# %% [markdown]
# A mistake was made initially where the weight decay was set to 1e4 instead of 1e-4, this led to a frustrating debugging session. The loss values were NaN, and it was hard to find it out. After checking the first couple of loss values. We saw that the loss became increasing exponentially larger, until it was so large that NaN was displayed. This is a great example of exploding gradients.
